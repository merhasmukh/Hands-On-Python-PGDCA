# %% [markdown]
# # Practical P40: Group Mini Project: Planning & Architecture
# **Learning Outcome**: Plan and scaffold a complete group AI Python application.
#
# ## Architectural Separations of Concerns
# When designing a system within groups, divide the components logically:
# 1. **Core Processing Library**: Handles reading configuration variables and making raw HTTP API connections.
# 2. **Orchestrator pipeline module**: Formats, cleans, chunks and filters models inputs.
# 3. **UIs Dashboards Layer**: Exposes Streamlit widgets, handles layout formatting, and outputs download options.
#
# ## Group Scaffold Structure Template
# Create a clean directory layout before committing team code branches:

# %%
import os
project_name = 'smart_study_assistant'
dirs = [
    os.path.join(project_name, 'data'),
    os.path.join(project_name, 'src'),
    os.path.join(project_name, 'src', 'tasks'),
    os.path.join(project_name, 'app'),
]
for d in dirs:
    os.makedirs(d, exist_ok=True)
    print('Created scaffold directory:', d)
