# %% [markdown]
# # Practical P42: Group Mini Project: Polish & Final Presentation
# **Learning Outcome**: Present a complete, documented, version-controlled AI Python application.
#
# ## Final Verification Checklist before submission:
# 1. **Git Status**: Are all `.env` files and compilation cache items listed inside `.gitignore`? Did you push all files?
# 2. **Readability & documentation**: Does your root project folder contain a README describing installations, environment keys, CLI parameters, or Streamlit usage steps?
# 3. **Exception Handling**: Do files loading or API calling modules wrap tasks inside try-except scopes to logs connection issues or file errors?
# 4. **Aesthetic UI**: Are status notifications wrapped inside spinners (`st.spinner()`) or alerts (`st.success()`)?
