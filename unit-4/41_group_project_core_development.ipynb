# %% [markdown]
# # Practical P41: Group Mini Project: Core Development
# **Learning Outcome**: Core project pipeline working and integrated across team members.
#
# ## Integrating team contributions
# During integration stages, merge team components inside structured modules. Build integration unit verification scripts to verify data flow from inputs to final outputs before launching UI wrappers.

# %%
# Verify modular logic components interface together
def mock_extract_text(file_path):
    return "Sample notes: Vector databases store embeddings for query retrieval."

def mock_generate_questions(text):
    return ["What do vector databases store?", "Why are embeddings useful?"]

# Integration check
def run_integrated_pipeline(path):
    notes = mock_extract_text(path)
    questions = mock_generate_questions(notes)
    print('Extracted input notes details:', notes)
    print('Generated quiz questions list:', questions)
    return len(questions) == 2

assert run_integrated_pipeline('data/lecture_1.txt') == True
print('Pipeline Integration Test Passed!')
